# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCarolvzz/ALGESTDADOS20261/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 3

print (a + b)    # Adição
print (a - b)    # Subtração
print (a * b)    # Multiplicaçaõ
print (a / b)    # Divisão real
print (a // b)   # Divisão int
print (a % b)    # Modulo
print (a ** b)   # 1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
nota = 7.5

print (nota >= 6.0)
print (nota == 10.0)
print (nota != 5.0)
print (nota < 5.0)
# Out:
# True
# False
# True
# False

# %%
idade = 17
renda = 1500.0
print(idade >= 18 and renda >= 1200)
print(idade >= 18 or renda >= 1200)
tem_debito = False
print(not tem_debito)
# Out:
# False
# True
# True

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 3 ** 2)
print(10 / (2 + 3))

X = 3 + 2 * 4 > 10 and not False
print(X)
# Out:
# 14
# 20
# 512
# 2.0
# True

# %%
#2Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.

a = 15
b = 4

print(15 + 4)
print(15 - 4)
print(15 * 4)
print(15 / 4)
print(15 // 4)
print(15 % 4)
print(15 ** 4)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
#2Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:
#quantos grupos completos serão formados
#quantos alunos sobrarão

a = 37
b = 5
print(37 // 5)
print(37 - 5)
# Out:
# 7
# 32

# %%
#3Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem:
#A área do retângulo é: X

x = 8.5 * 3.2
print(f'Area do retangulo {x}')
# Out:
# Area do retangulo 27.200000000000003
