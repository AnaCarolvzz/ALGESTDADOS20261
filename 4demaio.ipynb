# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCarolvzz/ALGESTDADOS20261/blob/main/4demaio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#todos os alunos em uma unica variavel!
alunos = ['ana', 'bruno', 'carla', 'diego', 'elena']

#percorrendo todos com apenas 2 linhas:
for aluno in alunos:
    print(aluno)
# Out:
# ana
# bruno
# carla
# diego
# elena

# %%
notas= [6, 6.5, 7, 5, 9]
print(f'{notas[0]} e {notas[-1]}')

notas[1] = 10
print(notas)
notas.append(9)
print(notas)
print(f'quant.denotas:{len(notas)}')
# Out:
# 6 e 9
# [6, 10, 7, 5, 9]
# [6, 10, 7, 5, 9, 9]
# quant.denotas:6

# %%
turma = ['joao', 'arthur', 'carol', 'isa']
#a
print('letra A:')
for aluno in turma:
    print(f'presente: {aluno}')
turma.append('ana')
#b
print('\nletra b:')
for aluno in turma:
    print(f'presente: {aluno}')
# Out:
# letra A:
# presente: joao
# presente: arthur
# presente: carol
# presente: isa
#
# letra b:
# presente: joao
# presente: arthur
# presente: carol
# presente: isa
# presente: ana

# %%
valores = [8, 7, 6, 5, 4]
print(valores)
